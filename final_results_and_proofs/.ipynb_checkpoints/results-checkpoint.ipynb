# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
) #Accuracy for Normal vfdt
# Plotting the Graph
plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %% [markdown]
# <b>centralised with whole data at once vs federated</b>

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.725,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %% [markdown]
# <b> with whole dataset at once </b><br>
# accuracy with centralised machine learning : 0.72

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.8051,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.8223,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.8503,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.8542,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.8638,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.9221,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %% [markdown]
# <b> No shuffling</b><br>

# %%
#Scenario 1: 2 client 200 communication round ; max_iteration= 2; data partition : 200(fed), 100(centralised) ; comm_Round:200
import numpy as np
import matplotlib.pyplot as plt

# Dataset
x1 = np.array([a for a in range(1,201)])
#x1 = np.arange(0,1200000,500)
#{'accuracy': [(0, 0.098), (1, 0.7259), (2, 0.8294), (3, 0.8552), (4, 0.8596), (5, 0.8685), (6, 0.8713), (7, 0.8794), (8, 0.8795), (9, 0.8842), (10, 0.8863)]}
y1 = np.array([0.6804,0.7119,0.7123,0.8039,0.8481,0.8559,0.8585,0.8634,0.8657,0.8688,0.8715,0.8762,0.8838,0.8881,0.8912,0.8916,0.8933,0.8935,0.8963,0.8963,0.9003,0.9008,0.9008,0.9018,0.9018,0.9021,0.9027,0.9026,0.9032,0.9029,0.9032,0.904,0.9037,0.9039,0.904,0.9042,0.9046,0.9048,0.9048,0.9057,0.9055,0.9062,0.9065,0.9067,0.9072,0.9076,0.9077,0.9076,0.9075,0.9081,0.9077,0.9082,0.9081,0.9088,0.9086,0.9091,0.9084,0.9093,0.9087,0.9093,0.9088,0.9092,0.9088,0.9097,0.9084,0.9099,0.9092,0.9101,0.9095,0.9103,0.9099,0.9109,0.9106,0.911,0.9107,0.9111,0.9109,0.9116,0.9115,0.912,0.9123,0.9122,0.9125,0.9128,0.9127,0.913,0.913,0.9133,0.9133,0.9133,0.9137,0.9133,0.914,0.9136,0.9141,0.914,0.9144,0.9143,0.9148,0.9143,0.9149,0.9144,0.9153,0.9145,0.915,0.9145,0.9152,0.9146,0.9154,0.915,0.9153,0.9152,0.9154,0.9153,0.9154,0.9154,0.9156,0.9156,0.9157,0.9156,0.9157,0.9157,0.9156,0.916,0.9157,0.916,0.9158,0.9159,0.916,0.9159,0.9162,0.9158,0.9163,0.9159,0.9161,0.9159,0.9165,0.9162,0.9167,0.9163,0.9168,0.9164,0.917,0.9165,0.9173,0.9169,0.9174,0.9173,0.9173,0.9174,0.9176,0.9178,0.9175,0.9178,0.9174,0.9177,0.9174,0.9177,0.9175,0.9177,0.9177,0.9178,0.918,0.9179,0.9181,0.9181,0.9181,0.9181,0.9181,0.918,0.9181,0.9181,0.918,0.9183,0.9179,0.9183,0.918,0.9183,0.9179,0.9182,0.918,0.9183,0.918,0.9184, 0.918,0.9183,0.918,0.9183,0.9178,0.9183,0.9177,0.9184,0.9178, 0.9185, 0.9178, 0.9185, 0.9178, 0.9185, 0.9179, 0.9186])
x2 = np.array([ a for a in range(1,201)])
y2 = np.repeat(0.6626,200)
#y2 = np.array([0.6887, 0.6556, 0.6617, 0.6415, 0.6678, 0.7087, 0.6809, 0.7007, 0.7476, 0.6068, 0.682, 0.6533, 0.6665, 0.7271, 0.6639, 0.6725, 0.6853, 0.7239, 0.6949, 0.7639, 0.7076, 0.7196, 0.6236, 0.7039, 0.7038, 0.7093, 0.6567, 0.7451, 0.5795, 0.7003, 0.6551, 0.7117, 0.6271, 0.7295, 0.641, 0.7169, 0.6514, 0.6565, 0.7414, 0.6511, 0.693, 0.7208, 0.6633, 0.7002, 0.7016, 0.6837, 0.7745, 0.7497, 0.6903, 0.6922, 0.6953, 0.6797, 0.7082, 0.7423, 0.6507, 0.7083, 0.6651, 0.7138, 0.774, 0.6435, 0.7826, 0.6589, 0.7059, 0.7958, 0.6833, 0.6806, 0.651, 0.6163, 0.6905, 0.7875, 0.6776, 0.6112, 0.7128, 0.7626, 0.6777, 0.7038, 0.7129, 0.7509, 0.6422, 0.6689, 0.7635, 0.7171, 0.7182, 0.7288, 0.6783, 0.7569, 0.7295, 0.6492, 0.6325, 0.7933, 0.7162, 0.6545, 0.6367, 0.6385, 0.738, 0.7438, 0.6827, 0.6977, 0.7023, 0.7009, 0.6491, 0.7, 0.652, 0.6667, 0.7068, 0.7394, 0.6675, 0.7374, 0.7121, 0.6647, 0.7076, 0.7345, 0.6447, 0.722, 0.7134, 0.7668, 0.7261, 0.7476, 0.6659, 0.6873, 0.6899, 0.7401, 0.6317, 0.6136, 0.7099, 0.673, 0.6553, 0.7489, 0.6996, 0.68, 0.6509, 0.5922, 0.6739, 0.7238, 0.7455, 0.662, 0.736, 0.6763, 0.6209, 0.7465, 0.6734, 0.6504, 0.7551, 0.5534, 0.7552, 0.5588, 0.6033, 0.6645, 0.7546, 0.7514, 0.6783, 0.732, 0.6617, 0.6939, 0.5779, 0.7454, 0.7581, 0.6533, 0.5979, 0.6646, 0.6432, 0.7399, 0.7131, 0.6724, 0.712, 0.6416, 0.6295, 0.6478, 0.6433, 0.7478, 0.6415, 0.7262, 0.6588, 0.6762, 0.7434, 0.6589, 0.6553, 0.7008, 0.6744, 0.7015, 0.7284, 0.718, 0.785, 0.613, 0.6456, 0.691, 0.7207, 0.7614, 0.7947, 0.7715, 0.7215, 0.7313, 0.6415, 0.7416, 0.6325, 0.6434, 0.7823, 0.6101, 0.7185, 0.7441]
#Accuracy for Normal vfdt
# Plotting the Graph

plt.plot(x1, y1, label = "Fed Learning")
plt.plot(x2,y2, label = "Centralised ML")

plt.title("Mnist Dataset Scenario 1 ")
plt.xlabel("communication round ")
plt.grid()

#plt.legend()
plt.ylabel("accuracy")
plt.show()

# %% [markdown]
# <b>Data for accuracy</b> <br>
# <b>clients=2 |divided into equal partition </b><br>
# [0.6804,0.7119,0.7123,0.8039,0.8481,0.8559,0.8585,0.8634,0.8657,0.8688,0.8715,0.8762,0.8838,0.8881,0.8912,0.8916,0.8933,0.8935,0.8963,0.8963,0.9003,0.9008,0.9008,0.9018,0.9018,0.9021,0.9027,0.9026,0.9032,0.9029,0.9032,0.904,0.9037,0.9039,0.904,0.9042,0.9046,0.9048,0.9048,0.9057,0.9055,0.9062,0.9065,0.9067,0.9072,0.9076,0.9077,0.9076,0.9075,0.9081,0.9077,0.9082,0.9081,0.9088,0.9086,0.9091,0.9084,0.9093,0.9087,0.9093,0.9088,0.9092,0.9088,0.9097,0.9084,0.9099,0.9092,0.9101,0.9095,0.9103,0.9099,0.9109,0.9106,0.911,0.9107,0.9111,0.9109,0.9116,0.9115,0.912,0.9123,0.9122,0.9125,0.9128,0.9127,0.913,0.913,0.9133,0.9133,0.9133,0.9137,0.9133,0.914,0.9136,0.9141,0.914,0.9144,0.9143,0.9148,0.9143,0.9149,0.9144,0.9153,0.9145,0.915,0.9145,0.9152,0.9146,0.9154,0.915,0.9153,0.9152,0.9154,0.9153,0.9154,0.9154,0.9156,0.9156,0.9157,0.9156,0.9157,0.9157,0.9156,0.916,0.9157,0.916,0.9158,0.9159,0.916,0.9159,0.9162,0.9158,0.9163,0.9159,0.9161,0.9159,0.9165,0.9162,0.9167,0.9163,0.9168,0.9164,0.917,0.9165,0.9173,0.9169,0.9174,0.9173,0.9173,0.9174,0.9176,0.9178,0.9175,0.9178,0.9174,0.9177,0.9174,0.9177,0.9175,0.9177,0.9177,0.9178,0.918,0.9179,0.9181,0.9181,0.9181,0.9181,0.9181,0.918,0.9181,0.9181,0.918,0.9183,0.9179,0.9183,0.918,0.9183,0.9179,0.9182,0.918,0.9183,0.918,0.9184, 0.918,0.9183,0.918,0.9183,0.9178,0.9183,0.9177,0.9184,0.9178, 0.9185, 0.9178, 0.9185, 0.9178, 0.9185, 0.9179, 0.9186]

# %% [markdown]
# <b>Data for accuracy calculation</b><br>
# <b>Communication round = 200 and above settings<br></b>
# <b>accuracy for federated </b> <br>
# [ 0.8485, 0.8506,  0.8632,  0.8766,  0.8721, 0.8741,  0.8775,  0.8754,  0.8812,  0.8805,  0.882,  0.88,  0.8782, 0.8737, 0.8683, 0.8766,  0.875,  0.8748,  0.8714,  0.8765,  0.8719,  0.8809,  0.8741,  0.8718,  0.8688,  0.8764,  0.878,  0.875,  0.8661,  0.8678,  0.8668, 0.8618, 0.867,  0.8746, 0.8759, 0.868,  0.8599,  0.8677,  0.8799,  0.8806, 0.8787,  0.8724,  0.8765,  0.8731,  0.8705,  0.88,  0.8721,  0.8727,  0.8742,  0.8695,  0.8638,  0.8712,  0.8715,  0.8737,  0.8803,  0.8804,  0.873,  0.8815,  0.8735,  0.8745,  0.8744,  0.8704,  0.8689,  0.876, 0.8822,  0.8793,  0.8747,  0.8807,  0.8791, 0.8755,  0.8822,  0.8794,  0.8799,  0.8804, 0.8764,  0.8734,  0.8709,  0.8686,  0.879,  0.8779,  0.8715,  0.87,  0.8764,  0.8778,  0.8768,  0.8766,  0.8752,  0.8804,  0.8795,  0.8726,  0.8779,  0.8759,  0.8806,  0.8788,  0.8786,  0.8768,  0.8802,  0.8773,  0.8797,  0.8763,  0.8716,  0.8711,  0.88,  0.8797,  0.8821,  0.8791,  0.8773,  0.8722,  0.8635,  0.8604,  0.8668,  0.8714,  0.8681 , 0.8692,  0.8791, 0.8723,  0.8819,  0.8731,  0.8719,  0.8789,  0.8672,  0.8699,  0.8743,  0.8709,  0.8782, 0.878,  0.8796,  0.8742,  0.8706,  0.8744,  0.8774,  0.8821,  0.8803,  0.8795,  0.875,  0.8739,  0.8826 , 0.8757,  0.8708,  0.8634,  0.8693,  0.8788,  0.8763,  0.874,  0.8797 , 0.8782,  0.8762, 0.8729,  0.8754 , 0.879,  0.8732,  0.8775, 0.8762,  0.8758,  0.8775,  0.8783, 0.8727,  0.8811,  0.8755,  0.8797,  0.8791, 0.8718 , 0.8703,  0.862,  0.8714,  0.8751, 0.8797,  0.8743, 0.8702,  0.8742,  0.8702,  0.8766,  0.8666,  0.8729,  0.8748,  0.88,  0.8827, 0.8806,  0.8762,  0.8779,  0.8738 , 0.8773,  0.8722, 0.8813,  0.8786,  0.8809,  0.8768,  0.8759,  0.8717,  0.8804,  0.8722,  0.8803,  0.8793, 0.8786,  0.8749 , 0.8689 , 0.8685, 0.8715,  0.8764,  0.8741]
